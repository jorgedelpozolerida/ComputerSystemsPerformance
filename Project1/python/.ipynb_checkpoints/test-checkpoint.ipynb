# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
concurrect_df = pd.concat([pd.read_csv(f"../experiments/concurrent_output/experiment_{1}.csv", sep=";")]).reset_index(drop=True)

concurrect_df["total tuples"] = 2000000
concurrect_df["tuples per ms"] = concurrect_df["total tuples"].div(concurrect_df["Running Time (ms)"].values)
concurrect_df
# Out:
#     Threads  Hash_Bits  Running Time (ms)  total tuples  tuples per ms
# 0         1          1                178       2000000   11235.955056
# 1         2          1                348       2000000    5747.126437
# 2         4          1                326       2000000    6134.969325
# 3         8          1                480       2000000    4166.666667
# 4         1          2                185       2000000   10810.810811
# ..      ...        ...                ...           ...            ...
# 75        8         19                737       2000000    2713.704206
# 76        1         20                300       2000000    6666.666667
# 77        2         20                338       2000000    5917.159763
# 78        4         20                526       2000000    3802.281369
# 79        8         20                752       2000000    2659.574468
#
# [80 rows x 5 columns]

# %%
sb.lineplot(data=concurrect_df, x="Hash_Bits", y="tuples per ms", hue="Threads").set(title="Concurrent Output")
# Out:
# [Text(0.5, 1.0, 'Concurrent Output')]

# %%
ind_df = pd.concat([pd.read_csv(f"../experiments/independent_output/experiment_{1}.csv", sep=";")]).reset_index(drop=True)

ind_df["total tuples"] = 2000000
ind_df["tuples per ms"] = ind_df["total tuples"].div(ind_df["Running Time (ms)"].values)
ind_df
# Out:
#     Threads  Hash_Bits  Running Time (ms)  total tuples  tuples per ms
# 0         1          1                203       2000000    9852.216749
# 1         2          1                113       2000000   17699.115044
# 2         4          1                 88       2000000   22727.272727
# 3         8          1                 69       2000000   28985.507246
# 4         1          2                211       2000000    9478.672986
# ..      ...        ...                ...           ...            ...
# 75        8         19                130       2000000   15384.615385
# 76        1         20               1043       2000000    1917.545542
# 77        2         20                619       2000000    3231.017771
# 78        4         20                290       2000000    6896.551724
# 79        8         20                118       2000000   16949.152542
#
# [80 rows x 5 columns]

# %%
sb.lineplot(data=ind_df, x="Hash_Bits", y="tuples per ms", hue="Threads").set(title="Independent Output")
# Out:
# [Text(0.5, 1.0, 'Independent Output')]
